# %%
print("hello world")
# Out:
# hello world

# %%
a=10

# %%
a
# Out:
# 10

# %%
a=5
f=29.13
name="Noshin Tabassum Juthi"
b=True
print(type(a))
print(type(f))
print(type(name))
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
